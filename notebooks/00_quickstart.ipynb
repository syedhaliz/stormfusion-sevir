# %% [markdown]
# # StormFusion Quickstart
# Smoke import & a dummy forward pass.

# %%
import torch
from stormfusion.models.unet2d import UNet2D
x = torch.randn(1, 13, 192, 192)
m = UNet2D(in_channels=13, out_channels=12)
y = m(x)
print(tuple(y.shape))
